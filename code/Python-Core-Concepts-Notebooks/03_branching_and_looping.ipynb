# %% [markdown]
# ## Branching and Looping

# %% [markdown]
# 1. **Guess a number game**
# The computer picks a random number from 1 to 5, the player tries to guess. The player may have the flexibility to enter the number in an expression format.

# %%
from random import randint
while True:
    num=randint(1,5)
    guess=int(input("Enter a number [1-5]:"))
    if guess==num:
        print("Right",num,"is the correct number!!")
        break
    else:
        print("The number is",num)
    i=input("Do you want to continue[y/n]: ")
    if i=='n'or i=='N':
        print("Thnaks for playing!!")
        break
# Out:
# The number is 4
# The number is 3
# Thnaks for playing!!

# %% [markdown]
# 2. **Kids Multiplication Table**
#     Write a multiplication game program for kids. The program should give the player ten randomly generated multiplication questions to do. After each, the program should tell them whether they got it right or wrong and what the correct answer is.
#
#     Sample Output:
#     Question 1: 3 x 4 = 12
#     Right!
#     Question 2:8 x 6 = 44
#     Wrong. The answer is 48.
#     Question 10: 7 x 7 = 49
#     Right!

# %%
from random import randint
for i in range(1,11):
    num1=randint(1,10)
    num2=randint(1,10)
    prod=num1*num2
    ch=int(input(f"Question {i}: {num1} x {num2}="))
    print("Question",i,":",num1,"x",num2,"=",ch)
    if(prod==ch):
        print("Right!")
    else:
        print("Wrong. The answer is",prod)
# Out:
# Question 1 : 2 x 8 = 16
# Right!
# Question 2 : 1 x 5 = 5
# Right!
# Question 3 : 6 x 9 = 54
# Right!
# Question 4 : 3 x 7 = 21
# Right!
# Question 5 : 1 x 8 = 8
# Right!
# Question 6 : 3 x 4 = 12
# Right!
# Question 7 : 4 x 7 = 28
# Right!
# Question 8 : 5 x 2 = 10
# Right!
# Question 9 : 1 x 1 = 1
# Right!
# Question 10 : 10 x 4 = 40
# Right!

# %% [markdown]
# 3. Check a list contains even number or not
#     numbers = [11,33,55,39,55,75,37,21,23,41,13]

# %%
n=int(input("Enter no. of elements in the list:"))
value=False
res=0
for i in range(n):
    num=int(input(f"Enter element {i+1}:"))
    if num%2==0:
        value=True
        res=num
        break
if value==True:
    print(f"Even no. {res} is present in the list")
else:
    print("The list entered doesn't contain any even no.")
# Out:
# The list entered doesn't contain any even no.

# %% [markdown]
# 4. Read N and generate the Fibonacci sequence upto N.

# %%
n=int(input("Enter no. of terms for Fibonacci Series:"))
n1=0
n2=1
for i in range(n):
    print(n1)
    temp=n2
    n2=n1+n2
    n1=temp
# Out:
# 0
# 1
# 1
# 2
# 3

# %% [markdown]
# 5. Use a for loop to print a box like the one below. Allow the user to specify how wide and how high the box should be. [Hint: print('*'*10) prints ten asterisks.]
#
#     ```bash
#         **********
#         **********
#         **********
#     ```

# %%
length=int(input("Enter Length of the Box:"))
height=int(input("Enter Width of the Box:"))
for i in range(height):
    print("*"*length)
# Out:
# **********
# **********
# **********

# %% [markdown]
# 6. Use loop to print a box like the one below. Allow the user to specify how wide and how high
# the box should be.
#
#     ```bash
#         **********
#         *        *
#         *        *
#         *        *
#         **********
#     ```

# %%
length = int(input("Enter Length of the Box: "))
width = int(input("Enter Width of the Box: "))
if length <= 0 or width <= 0:
    print("Invalid input")
else:
    print("*" * length)
    for i in range(width - 2):
        if length == 1:
            print("*")
        else:
            print("*" + " " * (length - 2) + "*")
    if width > 1:
        print("*" * length)
# Out:
# *****
# *   *
# *****

# %% [markdown]
# 7. Use for loops to print a diamond like the one below. Allow the user to specify how high the
# diamond should be.
#
# ```bash
#        *
#       ***
#      *****
#     *******
#      *****
#       ***
#        *
# ```

# %%
height = int(input("Enter the height of diamond (odd number): "))

if height % 2 == 0:
    print("Height must be an odd number.")
else:
    midpoint = height // 2 + 1
    for i in range(1, height + 1, 2):
        spaces = (height - i) // 2
        print("  " * spaces + "* " * i)
        if i == height:
            break
    for i in range(height - 2, 0, -2):
        spaces = (height - i) // 2
        print("  " * spaces + "* " * i)
# Out:
#     *
#   * * *
# * * * * *
#   * * *
#     *

# %% [markdown]
# 8. Write a program that lets the user play Rock-Paper-Scissors against the computer. There should be five rounds, and after those five rounds, your program should print out who won and lost or that there is a tie.

# %%
import random
choices = ["rock", "paper", "scissors"]
user_score = 0
computer_score = 0
rounds = 1
while rounds <= 5:
    print(f"\nRound {rounds}")
    user = input("Enter choice [rock, paper, scissors]: ").strip().lower()
    if user not in choices:
        print("Invalid Choice")
        continue
    comp = random.choice(choices)
    print("Your Choice is", user)
    print("Computer choice is", comp)
    if user == comp:
        print("This round is tie!")
        user_score += 1
        computer_score += 1
    elif (user == "rock" and comp == "scissors") or (user == "scissors" and comp == "paper") or (user == "paper" and comp == "rock"):
        print("You win this round!!")
        user_score += 1
    else:
        print("You lose this round!!")
        computer_score += 1
    rounds += 1
print(f"\nComputer Score: {computer_score}, User Score: {user_score}")
if user_score > computer_score:
    print("You win this game!!!")
elif user_score == computer_score:
    print("This game is a tie!!!")
else:
    print("You lose this game!!!")
# Out:
# Round 1
# Your Choice is rock
# Computer choice is paper
# You lose this round!!
#
# Round 2
# Your Choice is paper
# Computer choice is paper
# This round is tie!
#
# Round 3
# Your Choice is scissors
# Computer choice is rock
# You lose this round!!
#
# Round 4
# Your Choice is paper
# Computer choice is rock
# You win this round!!
#
# Round 5
# Your Choice is scissors
# Computer choice is paper
# You win this round!!
#
# Computer Score: 3, User Score: 3
# This game is a tie!!!

# %% [markdown]
# 9. Playing with Magic Words
#     Here a word ‘S’ of length ‘n’ is said to be magic word if it satisfies the following conditions:
#     - All letters of S are lowercase letters of the English alphabets.
#     - S<sub>i</sub>, the character in the i<sup>th</sup> position, is lexicographically smaller than S<sub>n-1-i</sub> for all even i from 0 to n/2
#     - S<sub>i</sub> is lexicographically greater than S<sub>n-1-i</sub> for all odd i from 0 to n/2
#
#     For example, the word “difference” is a magic word, while “similar” is not.
#     Given a word, write python code to check whether the word is magic or not.

# %%
word = input("Enter a word: ").strip()
n = len(word)
if not (word.isalpha() and word.islower()):
    print(f"{word} is not a magic word")
else:
    magic = True
    for i in range(n // 2):
        left = word[i]
        right = word[n - 1 - i]
        if i % 2 == 0:
            if not (left < right):
                magic = False
                break
        else:
            if not (left > right):
                magic = False
                break
    if magic:
        print(f"{word} is a magic word")
    else:
        print(f"{word} is not a magic word")
# Out:
# difference is a magic word
