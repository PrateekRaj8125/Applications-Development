# %% [markdown]
# ## Assignment 1 [ input statement and operators ]

# %% [markdown]
# 1. Write a python program to input two numbers and do all basic arithmetic operations on
# them.

# %%
a=float(input("Enter first number: "))
b=float(input("Enter second number: "))
print(f"Addition:", a+b)
print(f"Subtraction:", a-b)
print(f"Multiplication:", a*b)
print(f"Division:", a/b)
print(f"Modulus:", a%b)
print(f"Exponent:", a**b)
print(f"Floor Divison:", a//b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 a=float(input("Enter first number: "))
#       2 b=float(input("Enter second number: "))
#       3 print(f"Addition:", a+b)
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# 2. Write a python program to input two number and swap their values without using any third
# variable.

# %%
a=int(input("Enter value for a: "))
b=int(input("Enter value for b: "))
print(f"Before swapping: a={a}, b={b}")
a,b = b,a
print(f"After swapping: a={a}, b={b}")
# Out:
# Before swapping: a=11, b=2
# After swapping: a=2, b=11

# %% [markdown]
# 3. Write a python program to input the temperature in Fahrenheit and change it to Celsius.

# %%
f=float(input("Enter temperature in ℉: "))
c=(f-32)*5/9
print(f"Temperature {f}℉ in Celsius: {c}℃")
# Out:
# Temperature 100.0℉ in Celsius: 37.77777777777778℃

# %% [markdown]
# 4. Write a python program to input the basic salary of a person and compute its TA (20% of
# basic), DA (120% of basic), HRA (30% of basic), Gross (basic + ta + da + hra).

# %%
basic = float(input("Enter basic salary: ₹"))
ta = 0.20 * basic
da = 1.20 * basic
hra = 0.30 * basic
gross = basic + ta + da + hra
print(f"TA: ₹{ta}\n DA: ₹{da}\n HRA: ₹{hra}\n Gross Salary: ₹{gross}")
# Out:
# TA: ₹20000.0
#  DA: ₹120000.0
#  HRA: ₹30000.0
#  Gross Salary: ₹270000.0

# %% [markdown]
# 5. Write a python program to swap three variables.

# %%
x = int(input("Enter x: "))
y = int(input("Enter y: "))
z = int(input("Enter z: "))
print(f"Before Swapping: x={x}, y={y}, z={z}")
x, y, z = y, z, x
print(f"After swapping: x={x}, y={y}, z={z}")
# Out:
# Before Swapping: x=11, y=15, z=20
# After swapping: x=15, y=20, z=11

# %% [markdown]
# 6. Write a python program to evaluate the expression 4x⁴+3y³-9z+6

# %%
x = float(input("Enter x: "))
y = float(input("Enter y: "))
z = float(input("Enter z: "))
result = 4*(x**4) + 3*(y**3) - 9*z + 6
print(f"Expression (4x⁴+3y³-9z+6) Result: {result}")
# Out:
# Expression (4x⁴+3y³-9z+6) Result: 2497.0

# %% [markdown]
# 7. Write a python program to take a input in uppercase and change it to lower case

# %%
text = input("Enter text in UPPERCASE: ")
print(f"Coverted text in lowercase: {text.lower()}")
# Out:
# Coverted text in lowercase: computer

# %% [markdown]
# 8. Write a python program to input the radius of a circle and print its area and perimeter.

# %%
import math
radius=int(input("Enter radius of a circle: "))
area=float(math.pi*(radius**2))
perimeter=float(2*math.pi*radius)
print(f"Area of circle: {area}")
print(f"Perimeter of circle: {perimeter}")
# Out:
# Area of circle: 153.93804002589985
# Perimeter of circle: 43.982297150257104

# %% [markdown]
# 9. Write a python program to input marks in 5 subjects of a student and print its average mark.

# %%
m1=int(input("Marks of Subject 1: "))
m2=int(input("Marks of Subject 2: "))
m3=int(input("Marks of Subject 3: "))
m4=int(input("Marks of Subject 4: "))
m5=int(input("Marks of Subject 5: "))
tm=(m1+m2+m3+m4+m5)
avg=float(tm/5)
print("Total Marks: ",tm, "\nAverage Marks: ", avg)
# Out:
# Total Marks:  400
# Average Marks:  80.0

# %% [markdown]
# 10. Write a python program to input a number and print its square, cube and fourth power.

# %%
n = float(input("Enter a number: "))
print(f"Square: {n**2}\n Cube: {n**3}\n Fourth Power: {n**4}")
# Out:
# Square: 9.0
#  Cube: 27.0
#  Fourth Power: 81.0

# %% [markdown]
# 11. Write a python program to input the sides of a triangle and print its area.

# %%
import math
a=float(input("Side a: "))
b=float(input("Side b: "))
c=float(input("Side c: "))
s=(a+b+c)/2
area = math.sqrt(s*(s-a)*(s-b)*(s-c))
print(f"Area of triangle: {area}")
# Out:
# Area of triangle: 18.33030277982336

# %% [markdown]
# 12. Write a python program to compute SI and CI.

# %%
p = float(input("Principal: ₹"))
r = float(input("Rate (%p.a.):"))
t = float(input("Time (in years): "))
si = (p * r * t) / 100
ci = p * (pow((1 + r / 100), t)) - p
print(f"Simple Interest: ₹{si}")
print(f"Compound Interest: ₹{ci}")
# Out:
# Simple Interest: ₹7500.0
# Compound Interest: ₹10610.31562164711

# %% [markdown]
# 13. Ask the user to enter a number x. Use the sep optional argument to print out x, 2x, 3x, 4x,
# and 5x, each separated by three dashes, like below.
# Enter a number: 7
# 7---14---21---28---35

# %%
x = int(input("Enter a number: "))
print(x, 2*x, 3*x, 4*x, 5*x, sep="---")
# Out:
# 2---4---6---8---10
